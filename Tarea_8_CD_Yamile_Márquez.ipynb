# %% [markdown]
# <a href="https://colab.research.google.com/github/Yamile222768/Tareas/blob/main/Tarea_8_CD_Yamile_M%C3%A1rquez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**TAREA ACTIVIDAD 08 - EJERCICIO DE REPRESENTACIÓN DE LA INFORMACIÓN**

# %%
import pandas as pd
df = pd.read_csv('temporal.csv')
df.head(10) #View first 10 data rows
# Out:
#           Mes  data science  machine learning  deep learning  categorical
# 0  2004-01-01            12                18              4            1
# 1  2004-02-01            12                21              2            1
# 2  2004-03-01             9                21              2            1
# 3  2004-04-01            10                16              4            1
# 4  2004-05-01             7                14              3            1
# 5  2004-06-01             9                17              3            1
# 6  2004-07-01             9                16              3            1
# 7  2004-08-01             7                14              3            1
# 8  2004-09-01            10                17              4            1
# 9  2004-10-01             8                17              4            1

# %%
df.describe()
# Out:
#        data science  machine learning  deep learning  categorical
# count    194.000000        194.000000     194.000000   194.000000
# mean      20.953608         27.396907      24.231959     0.257732
# std       23.951006         28.091490      34.476887     0.438517
# min        4.000000          7.000000       1.000000     0.000000
# 25%        6.000000          9.000000       2.000000     0.000000
# 50%        8.000000         13.000000       3.000000     0.000000
# 75%       26.750000         31.500000      34.000000     1.000000
# max      100.000000        100.000000     100.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Mes               194 non-null    object
#  1   data science      194 non-null    int64
#  2   machine learning  194 non-null    int64
#  3   deep learning     194 non-null    int64
#  4   categorical       194 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.7+ KB

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
df
# Out:
#             Mes  data science  machine learning  deep learning  categorical
# 0    2004-01-01            12                18              4            1
# 1    2004-02-01            12                21              2            1
# 2    2004-03-01             9                21              2            1
# 3    2004-04-01            10                16              4            1
# 4    2004-05-01             7                14              3            1
# 5    2004-06-01             9                17              3            1
# 6    2004-07-01             9                16              3            1
# 7    2004-08-01             7                14              3            1
# 8    2004-09-01            10                17              4            1
# 9    2004-10-01             8                17              4            1
# 10   2004-11-01             8                15              2            1
# 11   2004-12-01             8                16              2            1
# 12   2005-01-01            10                16              2            0
# 13   2005-02-01             9                14              3            0
# 14   2005-03-01             8                13              2            0
# 15   2005-04-01             8                12              3            0
# 16   2005-05-01             8                15              3            0
# 17   2005-06-01             8                12              3            0
# 18   2005-07-01             6                11              2            0
# 19   2005-08-01             9                10              2            0
# 20   2005-09-01             7                14              2            0
# 21   2005-10-01             7                16              3            0
# 22   2005-11-01             7                13              4            0
# 23   2005-12-01             5                13              2            0
# 24   2006-01-01             7                12              3            0
# 25   2006-02-01             7                12              3            0
# 26   2006-03-01             7                12              2            0
# 27   2006-04-01             7                12              2            0
# 28   2006-05-01             7                11              2            0
# 29   2006-06-01             6                10              2            0
# 30   2006-07-01             5                 9              1            0
# 31   2006-08-01             6                 9              2            0
# 32   2006-09-01             7                11              1            0
# 33   2006-10-01             6                11              2            0
# 34   2006-11-01             7                11              2            0
# 35   2006-12-01             4                 9              3            0
# 36   2007-01-01             6                11              2            0
# 37   2007-02-01             7                11              3            0
# 38   2007-03-01             6                 9              3            0
# 39   2007-04-01             5                10              3            0
# 40   2007-05-01             6                 9              1            0
# 41   2007-06-01             6                 9              2            0
# 42   2007-07-01             4                 9              2            0
# 43   2007-08-01             5                 9              3            0
# 44   2007-09-01             6                 9              2            0
# 45   2007-10-01             6                11              2            0
# 46   2007-11-01             6                10              2            0
# 47   2007-12-01             5                 8              3            0
# 48   2008-01-01             6                 9              2            1
# 49   2008-02-01             6                 9              2            1
# 50   2008-03-01             5                 8              3            1
# 51   2008-04-01             6                10              2            1
# 52   2008-05-01             5                 9              2            1
# 53   2008-06-01             5                 8              2            1
# 54   2008-07-01             5                 7              3            1
# 55   2008-08-01             5                 7              1            1
# 56   2008-09-01             6                 9              2            1
# 57   2008-10-01             6                10              2            1
# 58   2008-11-01             6                 9              2            1
# 59   2008-12-01             5                 8              2            1
# 60   2009-01-01             6                 8              3            0
# 61   2009-02-01             6                 9              3            0
# 62   2009-03-01             6                 8              2            0
# 63   2009-04-01             6                 9              3            0
# 64   2009-05-01             5                 8              2            0
# 65   2009-06-01             5                 8              2            0
# 66   2009-07-01             4                 8              2            0
# 67   2009-08-01             5                 8              2            0
# 68   2009-09-01             7                 8              3            0
# 69   2009-10-01             6                 9              2            0
# 70   2009-11-01             7                 9              2            0
# 71   2009-12-01             6                 8              2            0
# 72   2010-01-01             7                 8              2            0
# 73   2010-02-01             7                 9              2            0
# 74   2010-03-01             6                 9              2            0
# 75   2010-04-01             6                 9              2            0
# 76   2010-05-01             6                 8              2            0
# 77   2010-06-01             5                 8              2            0
# 78   2010-07-01             5                 8              3            0
# 79   2010-08-01             5                 8              2            0
# 80   2010-09-01             7                 9              2            0
# 81   2010-10-01             6                 9              3            0
# 82   2010-11-01             6                 9              3            0
# 83   2010-12-01             5                 9              2            0
# 84   2011-01-01             7                 8              3            0
# 85   2011-02-01             6                 9              2            0
# 86   2011-03-01             6                 9              3            0
# 87   2011-04-01             6                 9              2            0
# 88   2011-05-01             5                 9              3            0
# 89   2011-06-01             5                 8              2            0
# 90   2011-07-01             4                 7              2            0
# 91   2011-08-01             5                 8              2            0
# 92   2011-09-01             7                11              3            0
# 93   2011-10-01             7                12              3            0
# 94   2011-11-01             7                12              3            0
# 95   2011-12-01             6                10              2            0
# 96   2012-01-01             7                10              3            1
# 97   2012-02-01             7                11              3            1
# 98   2012-03-01             7                11              2            1
# 99   2012-04-01             6                11              3            1
# 100  2012-05-01             6                11              4            1
# 101  2012-06-01             6                10              3            1
# 102  2012-07-01             6                10              3            1
# 103  2012-08-01             7                10              3            1
# 104  2012-09-01            10                12              3            1
# 105  2012-10-01             8                13              4            1
# 106  2012-11-01             8                12              6            1
# 107  2012-12-01             6                11              4            1
# 108  2013-01-01             8                11              5            0
# 109  2013-02-01             8                12              4            0
# 110  2013-03-01             8                12              5            0
# 111  2013-04-01             9                13              6            0
# 112  2013-05-01             9                13              7            0
# 113  2013-06-01             8                12              5            0
# 114  2013-07-01             8                12              6            0
# 115  2013-08-01             9                11              6            0
# 116  2013-09-01            12                13              8            0
# 117  2013-10-01            11                16              7            0
# 118  2013-11-01            11                15              8            0
# 119  2013-12-01            10                14              8            0
# 120  2014-01-01            13                14              9            0
# 121  2014-02-01            12                16             10            0
# 122  2014-03-01            13                16             10            0
# 123  2014-04-01            13                17             10            0
# 124  2014-05-01            12                16             11            0
# 125  2014-06-01            12                15             10            0
# 126  2014-07-01            13                16              9            0
# 127  2014-08-01            16                16             11            0
# 128  2014-09-01            19                18             12            0
# 129  2014-10-01            17                18             12            0
# 130  2014-11-01            17                20             11            0
# 131  2014-12-01            16                18             17            0
# 132  2015-01-01            19                20             19            0
# 133  2015-02-01            18                21             20            0
# 134  2015-03-01            18                21             21            0
# 135  2015-04-01            20                24             19            0
# 136  2015-05-01            19                22             20            0
# 137  2015-06-01            20                24             23            0
# 138  2015-07-01            20                24             23            0
# 139  2015-08-01            23                23             22            0
# 140  2015-09-01            27                26             24            0
# 141  2015-10-01            25                27             24            0
# 142  2015-11-01            24                30             28            0
# 143  2015-12-01            22                28             28            0
# 144  2016-01-01            27                28             34            1
# 145  2016-02-01            27                32             34            1
# 146  2016-03-01            26                34             44            1
# 147  2016-04-01            27                34             44            1
# 148  2016-05-01            27                34             42            1
# 149  2016-06-01            27                36             46            1
# 150  2016-07-01            26                32             40            1
# 151  2016-08-01            29                34             41            1
# 152  2016-09-01            36                39             46            1
# 153  2016-10-01            33                42             52            1
# 154  2016-11-01            34                46             55            1
# 155  2016-12-01            33                46             59            1
# 156  2017-01-01            41                51             65            0
# 157  2017-02-01            42                56             69            0
# 158  2017-03-01            44                59             75            0
# 159  2017-04-01            42                61             76            0
# 160  2017-05-01            43                63             80            0
# 161  2017-06-01            43                65             78            0
# 162  2017-07-01            42                62             76            0
# 163  2017-08-01            47                64             84            0
# 164  2017-09-01            53                71             87            0
# 165  2017-10-01            53                75             89            0
# 166  2017-11-01            52                80             94            0
# 167  2017-12-01            48                72             91            0
# 168  2018-01-01            58                76             91            0
# 169  2018-02-01            57                80             93            0
# 170  2018-03-01            58                82             95            0
# 171  2018-04-01            58                82             95            0
# 172  2018-05-01            59                83             98            0
# 173  2018-06-01            57                81             90            0
# 174  2018-07-01            60                81             88            0
# 175  2018-08-01            64                82             87            0
# 176  2018-09-01            68                85             94            0
# 177  2018-10-01            70                90             97            0
# 178  2018-11-01            67                88             94            0
# 179  2018-12-01            61                81             87            0
# 180  2019-01-01            76                86             93            0
# 181  2019-02-01            77                93             95            0
# 182  2019-03-01            75                91             98            0
# 183  2019-04-01            77                92             98            0
# 184  2019-05-01            76                92             97            0
# 185  2019-06-01            80                93             96            0
# 186  2019-07-01            85                92             96            0
# 187  2019-08-01            88                93             92            0
# 188  2019-09-01            95               100            100            0
# 189  2019-10-01            90                98             98            0
# 190  2019-11-01            87                97             96            0
# 191  2019-12-01            81                89             91            0
# 192  2020-01-01            94                94             93            1
# 193  2020-02-01           100                99             99            1

# %%
format_dict = {'data science':'${0:,.2f}', 'Mes':'{:%m-%Y}', 'machine learning':'{:.2%}'}

#We make sure that the Month column has datetime format
df['Mes'] = pd.to_datetime(df['Mes'])

#We apply the style to the visualization
df.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3efd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3efd_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_d3efd_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_d3efd_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_d3efd_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_d3efd_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3efd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3efd_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_d3efd_row0_col1" class="data row0 col1" >$12.00</td>
#       <td id="T_d3efd_row0_col2" class="data row0 col2" >1800.00%</td>
#       <td id="T_d3efd_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_d3efd_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d3efd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3efd_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_d3efd_row1_col1" class="data row1 col1" >$12.00</td>
#       <td id="T_d3efd_row1_col2" class="data row1 col2" >2100.00%</td>
#       <td id="T_d3efd_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_d3efd_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d3efd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3efd_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_d3efd_row2_col1" class="data row2 col1" >$9.00</td>
#       <td id="T_d3efd_row2_col2" class="data row2 col2" >2100.00%</td>
#       <td id="T_d3efd_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_d3efd_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d3efd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3efd_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_d3efd_row3_col1" class="data row3 col1" >$10.00</td>
#       <td id="T_d3efd_row3_col2" class="data row3 col2" >1600.00%</td>
#       <td id="T_d3efd_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_d3efd_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d3efd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3efd_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_d3efd_row4_col1" class="data row4 col1" >$7.00</td>
#       <td id="T_d3efd_row4_col2" class="data row4 col2" >1400.00%</td>
#       <td id="T_d3efd_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_d3efd_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
format_dict = {'Mes':'{:%m-%Y}'} #Simplified format dictionary with values that do make sense for our data
df.head().style.format(format_dict).highlight_max(color='darkgreen').highlight_min(color='#ff0000')
# Out:
# <style type="text/css">
# #T_d9f31_row0_col0, #T_d9f31_row1_col3, #T_d9f31_row2_col3, #T_d9f31_row4_col1, #T_d9f31_row4_col2 {
#   background-color: #ff0000;
# }
# #T_d9f31_row0_col1, #T_d9f31_row0_col3, #T_d9f31_row1_col1, #T_d9f31_row1_col2, #T_d9f31_row2_col2, #T_d9f31_row3_col3, #T_d9f31_row4_col0 {
#   background-color: darkgreen;
# }
# #T_d9f31_row0_col4, #T_d9f31_row1_col4, #T_d9f31_row2_col4, #T_d9f31_row3_col4, #T_d9f31_row4_col4 {
#   background-color: darkgreen;
#   background-color: #ff0000;
# }
# </style>
# <table id="T_d9f31" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9f31_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_d9f31_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_d9f31_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_d9f31_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_d9f31_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9f31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9f31_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_d9f31_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_d9f31_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_d9f31_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_d9f31_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9f31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9f31_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_d9f31_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_d9f31_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_d9f31_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_d9f31_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9f31_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9f31_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_d9f31_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_d9f31_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_d9f31_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_d9f31_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9f31_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9f31_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_d9f31_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_d9f31_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_d9f31_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_d9f31_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9f31_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9f31_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_d9f31_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_d9f31_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_d9f31_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_d9f31_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head(10).style.format(format_dict).background_gradient(subset=['data science', 'machine learning'], cmap='BuGn')
# Out:
# <style type="text/css">
# #T_7805a_row0_col1, #T_7805a_row1_col1, #T_7805a_row1_col2, #T_7805a_row2_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7805a_row0_col2 {
#   background-color: #51b689;
#   color: #f1f1f1;
# }
# #T_7805a_row2_col1, #T_7805a_row5_col1, #T_7805a_row6_col1 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_7805a_row3_col1, #T_7805a_row8_col1 {
#   background-color: #48b27f;
#   color: #f1f1f1;
# }
# #T_7805a_row3_col2, #T_7805a_row6_col2 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_7805a_row4_col1, #T_7805a_row4_col2, #T_7805a_row7_col1, #T_7805a_row7_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_7805a_row5_col2, #T_7805a_row8_col2, #T_7805a_row9_col2 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_7805a_row9_col1 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# </style>
# <table id="T_7805a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7805a_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_7805a_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_7805a_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_7805a_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_7805a_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7805a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7805a_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_7805a_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_7805a_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_7805a_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_7805a_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7805a_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_7805a_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_7805a_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_7805a_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_7805a_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7805a_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_7805a_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_7805a_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_7805a_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_7805a_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7805a_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_7805a_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_7805a_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_7805a_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_7805a_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7805a_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_7805a_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_7805a_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_7805a_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_7805a_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7805a_row5_col0" class="data row5 col0" >06-2004</td>
#       <td id="T_7805a_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_7805a_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_7805a_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_7805a_row5_col4" class="data row5 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7805a_row6_col0" class="data row6 col0" >07-2004</td>
#       <td id="T_7805a_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_7805a_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_7805a_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_7805a_row6_col4" class="data row6 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7805a_row7_col0" class="data row7 col0" >08-2004</td>
#       <td id="T_7805a_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_7805a_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_7805a_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_7805a_row7_col4" class="data row7 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7805a_row8_col0" class="data row8 col0" >09-2004</td>
#       <td id="T_7805a_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_7805a_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_7805a_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_7805a_row8_col4" class="data row8 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7805a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7805a_row9_col0" class="data row9 col0" >10-2004</td>
#       <td id="T_7805a_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_7805a_row9_col2" class="data row9 col2" >17</td>
#       <td id="T_7805a_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_7805a_row9_col4" class="data row9 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head().style.format(format_dict).bar(color='red', subset=['data science', 'deep learning'])
# Out:
# <style type="text/css">
# #T_18180_row0_col1, #T_18180_row0_col3, #T_18180_row1_col1, #T_18180_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, red 100.0%, transparent 100.0%);
# }
# #T_18180_row1_col3, #T_18180_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, red 50.0%, transparent 50.0%);
# }
# #T_18180_row2_col1, #T_18180_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, red 75.0%, transparent 75.0%);
# }
# #T_18180_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, red 83.3%, transparent 83.3%);
# }
# #T_18180_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, red 58.3%, transparent 58.3%);
# }
# </style>
# <table id="T_18180" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18180_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_18180_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_18180_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_18180_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_18180_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18180_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18180_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_18180_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_18180_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_18180_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_18180_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_18180_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18180_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_18180_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_18180_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_18180_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_18180_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_18180_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18180_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_18180_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_18180_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_18180_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_18180_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_18180_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18180_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_18180_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_18180_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_18180_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_18180_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_18180_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18180_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_18180_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_18180_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_18180_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_18180_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head(10).style.format(format_dict).background_gradient(subset=['data science', 'machine learning'], cmap='BuGn').highlight_max(color='yellow')
# Out:
# <style type="text/css">
# #T_54503_row0_col1, #T_54503_row1_col1, #T_54503_row1_col2, #T_54503_row2_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: yellow;
# }
# #T_54503_row0_col2 {
#   background-color: #51b689;
#   color: #f1f1f1;
# }
# #T_54503_row0_col3, #T_54503_row0_col4, #T_54503_row1_col4, #T_54503_row2_col4, #T_54503_row3_col3, #T_54503_row3_col4, #T_54503_row4_col4, #T_54503_row5_col4, #T_54503_row6_col4, #T_54503_row7_col4, #T_54503_row8_col3, #T_54503_row8_col4, #T_54503_row9_col0, #T_54503_row9_col3, #T_54503_row9_col4 {
#   background-color: yellow;
# }
# #T_54503_row2_col1, #T_54503_row5_col1, #T_54503_row6_col1 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_54503_row3_col1, #T_54503_row8_col1 {
#   background-color: #48b27f;
#   color: #f1f1f1;
# }
# #T_54503_row3_col2, #T_54503_row6_col2 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_54503_row4_col1, #T_54503_row4_col2, #T_54503_row7_col1, #T_54503_row7_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_54503_row5_col2, #T_54503_row8_col2, #T_54503_row9_col2 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_54503_row9_col1 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# </style>
# <table id="T_54503" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54503_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_54503_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_54503_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_54503_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_54503_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54503_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54503_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_54503_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_54503_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_54503_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_54503_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54503_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_54503_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_54503_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_54503_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_54503_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54503_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_54503_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_54503_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_54503_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_54503_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54503_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_54503_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_54503_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_54503_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_54503_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_54503_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_54503_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_54503_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_54503_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_54503_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_54503_row5_col0" class="data row5 col0" >06-2004</td>
#       <td id="T_54503_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_54503_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_54503_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_54503_row5_col4" class="data row5 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_54503_row6_col0" class="data row6 col0" >07-2004</td>
#       <td id="T_54503_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_54503_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_54503_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_54503_row6_col4" class="data row6 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_54503_row7_col0" class="data row7 col0" >08-2004</td>
#       <td id="T_54503_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_54503_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_54503_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_54503_row7_col4" class="data row7 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_54503_row8_col0" class="data row8 col0" >09-2004</td>
#       <td id="T_54503_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_54503_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_54503_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_54503_row8_col4" class="data row8 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_54503_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_54503_row9_col0" class="data row9 col0" >10-2004</td>
#       <td id="T_54503_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_54503_row9_col2" class="data row9 col2" >17</td>
#       <td id="T_54503_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_54503_row9_col4" class="data row9 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Matplotlib**

# %%
import matplotlib.pyplot as plt
plt.plot(df['Mes'], df['data science'], label='data science') #The parameter label is to indicate the legend. This doesn't mean that it will be shown, we'll have to use another command that I'll explain later.

# %%
plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')

# %%
plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')
plt.xlabel('Date')
plt.ylabel('Popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)
plt.legend()

# %%
fig, axes = plt.subplots(2,2)
axes[0, 0].hist(df['data science'])
axes[0, 1].scatter(df['Mes'], df['data science'])
axes[1, 0].plot(df['Mes'], df['machine learning'])
axes[1, 1].plot(df['Mes'], df['deep learning'])

# %%
plt.plot(df['Mes'], df['data science'], 'r-')
plt.plot(df['Mes'], df['data science']*2, 'bs')
plt.plot(df['Mes'], df['data science']*3, 'g^')

# %%
plt.scatter(df['data science'], df['machine learning'])

# %%
plt.bar(df['Mes'], df['machine learning'], width=20)
# Out:
# <BarContainer object of 194 artists>

# %%
plt.hist(df['deep learning'], bins=15)
# Out:
# (array([117.,  14.,   5.,   6.,   2.,   3.,   6.,   1.,   2.,   1.,   1.,
#           5.,   1.,  13.,  17.]),
#  array([  1. ,   7.6,  14.2,  20.8,  27.4,  34. ,  40.6,  47.2,  53.8,
#          60.4,  67. ,  73.6,  80.2,  86.8,  93.4, 100. ]),
#  <BarContainer object of 15 artists>)

# %%
# !pip install pandas

import matplotlib.pyplot as plt
import pandas as pd

# Convert 'Mes' column to datetime objects
df['Mes'] = pd.to_datetime(df['Mes'])

# Graficar las líneas de cada columna
plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')

plt.xlabel('Date')
plt.ylabel('Popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)

# Agregar texto y anotación al gráfico
plt.text(pd.to_datetime('2014-01-01'), 80, r'$\lambda=1, r^2=0.8$') # Convert text x-coordinate to datetime
plt.annotate('Notice something?', xy=(pd.to_datetime('2014-01-01'), 30), xytext=(pd.to_datetime('2006-01-01'), 50), arrowprops={'facecolor':'red', 'shrink':0.05}) # Convert annotation coordinates to datetime

# Mostrar el gráfico
plt.legend()
plt.show()
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# **Seaborn**

# %%
import seaborn as sns
sns.set()
sns.scatterplot(x='Mes', y='data science', data=df)
# Out:
# <Axes: xlabel='Mes', ylabel='data science'>

# %%
sns.relplot(x='Mes', y='deep learning', hue='data science', size='machine learning', col='categorical', data=df)

# %%
# Seleccionar solo las columnas numéricas para la matriz de correlación
num_cols = ['data science', 'machine learning', 'deep learning']

# Convertir las columnas numéricas a valores numéricos si es necesario
for col in num_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Obtener la matriz de correlación solo para las columnas numéricas
correlation_matrix = df[num_cols].corr()

# Generar el heatmap
sns.heatmap(correlation_matrix, annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='categorical')

# %%
sns.jointplot(x='data science', y='machine learning', data=df)

# %%
sns.catplot(x='categorical', y='data science', kind='violin', data=df)

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(8, 4))
sns.scatterplot(x="Mes", y="deep learning", hue="categorical", data=df, ax=axes[0])
axes[0].set_title('Deep Learning')
sns.scatterplot(x="Mes", y="machine learning", hue="categorical", data=df, ax=axes[1])
axes[1].set_title('Machine Learning')
# Out:
# Text(0.5, 1.0, 'Machine Learning')

# %% [markdown]
# **Folium**

# %%
# %pip install folium
import folium
m1 = folium.Map(location=[41.38, 2.17], tiles='openstreetmap', zoom_start=18)
m1.save('map1.html')
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.8.30)

# %%
m2 = folium.Map(location=[41.38, 2.17], tiles='openstreetmap', zoom_start=16)

folium.Marker([41.38, 2.176], popup='<i>You can use whatever HTML code you want</i>', tooltip='click here').add_to(m2)
folium.Marker([41.38, 2.174], popup='<b>You can use whatever HTML code you want</b>', tooltip='dont click here').add_to(m2)

m2.save('map2.html')
